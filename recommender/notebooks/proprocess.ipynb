# %%
import sys
import os
from pathlib import Path

# Add parent directory to Python path
module_path = str(Path().absolute().parent)
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from data.preprocessor import FeaturePreprocessor

config_path = "../configs/preprocessing/feature_config.yaml"

preprocessor = FeaturePreprocessor(config_path)
preprocessor.config
# Out:
# 2025-04-01 21:43:45,225 - data.preprocessor - INFO - Successfully loaded configuration from ../configs/preprocessing/feature_config.yaml
# 2025-04-01 21:43:45,227 - data.preprocessor - INFO - Initialized FeaturePreprocessor with config from ../configs/preprocessing/feature_config.yaml
# {'user_features': {'demographics': [{'name': 'age',
#     'type': 'numerical',
#     'preprocessing': {'normalize': True, 'outlier_treatment': 'cap_3std'}},
#    {'name': 'gender',
#     'type': 'categorical',
#     'preprocessing': {'encoding': 'one_hot'}},
#    {'name': 'country',
#     'type': 'categorical',
#     'preprocessing': {'encoding': 'entity_embedding',
#      'min_frequency': 5,
#      'max_categories': 50}}],
#   'listening_behavior': [{'name': 'monthly_hours',
#     'type': 'numerical',
#     'preprocessing': {'normalize': True, 'log_transform': True}},
#    {'name': 'genre_diversity',
#     'type': 'numerical',
#     'preprocessing': {'normalize': True}},
#    {'name': 'top_genre',
# ...

# %%
train_data, val_data,test_data = preprocessor.preprocess("../data/spotify_1k_sample_data.csv", "../data/preprocessed_1k_data")
train_data.head()
# Out:
# 2025-04-01 21:46:16,395 - data.preprocessor - INFO - Starting preprocessing pipeline for ../data/spotify_1k_sample_data.csv
# 2025-04-01 21:46:16,427 - data.preprocessor - INFO - Successfully loaded data from ../data/spotify_1k_sample_data.csv: 1000 rows, 43 columns
# 2025-04-01 21:46:16,430 - data.preprocessor - INFO - Handling missing values
# 2025-04-01 21:46:16,444 - data.preprocessor - INFO - Completed missing value handling
# 2025-04-01 21:46:16,445 - data.preprocessor - INFO - Treating outliers in numerical features
# 2025-04-01 21:46:16,453 - data.preprocessor - INFO - Capped outliers for age: [-8.558249039192283, 84.07624903919228]
# 2025-04-01 21:46:16,454 - data.preprocessor - INFO - Completed outlier treatment
# 2025-04-01 21:46:16,455 - data.preprocessor - INFO - Fitting and applying normalization to numerical features
# 2025-04-01 21:46:16,464 - data.preprocessor - INFO - Normalized feature: age
# ...
